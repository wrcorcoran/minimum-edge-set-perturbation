# %% [markdown]
# # Greedy Addition For Correct Nodes

# %%
# these warnings are fine. you can ignore them.
import random, math
from CriticalNodes import CriticalEdge, CriticalEdges
import pickle

import sys
sys.path.append('../')
from CriticalNodes import CriticalEdge, CriticalEdges
sys.path.append('../../')
from util import *



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Imports finished.")
# Out:
# Imports finished.

# %%
max_rate = 0.1

# %%
### realistically, this should be the only function changing in your guys' notebooks
def checkCorrectClass(i, j, graph, threshold=1):
    return abs(graph.degree[i] - graph.degree[j]) <= threshold

# %% [markdown]
# ## Setting Up Dataset/Model/Ground Truth

# %%
dataset = Dataset(root='/tmp/Cora', name='Cora', device=device)
data, in_feats, h_feats, num_classes = dataset.get_data()

model = get_model('../', in_feats, h_feats, num_classes, "cora", Models.GCN)
ground_truth, orig_pred = get_ground_truth(model, data, Models.GCN, testMask=True)
print(ground_truth)
# Out:
# 0.745

# %%
labels = data.y

# %% [markdown]
# ## Experiments

# %% [markdown]
# **Note:** The ground truth here is $0.745$

# %%
G, x, y, train_mask, test_mask = convert_to_networkx(data)

homophilies = [0] * len(G.nodes())
degrees = [0] * len(G.nodes())
two_hop_neighborhood_sizes = [0] * len(G.nodes())

for n in G.nodes():
    homophilies[n] = get_node_homophily(G, n, y, y[n].item())
    degrees[n] = G.degree(n)
    two_hop_neighborhood_sizes[n] = nx.ego_graph(G, n, 2).number_of_nodes()

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()

for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, G):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))
# Out:
# 568322
# CPU times: user 8.01 s, sys: 21 ms, total: 8.03 s
# Wall time: 8.05 s

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_cora = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GCN, testMask=True)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(ground_truth, test_model(model, modified_graph, GCNtype=Models.GCN, testMask=True)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_cora.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/degree/cora/critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_cora)
# Out:
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 200  iterations!
# 250  iterations!
# 250  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  263.0  | Percentage change: 4.98%
# Miss Rate:  0.09931506849315064
# ----
# Average Degree: 4.758620689655173
# Min Degree: 2.0
# Max Degree: 10.0
# Min Homophily: 0.5
# Max Homophily: 1.0
# Average Homophily: 0.8359195402298851
# Min Two-hop Neighborhood Size: 2.0
# Max Two-hop Neighborhood Size: 46.5
# Average Two-hop Neighborhood Size: 16.724137931034484
# Ground Truth Classification Counts: [6, 1, 0, 11, 6, 4, 1]
# ----
# Edge between nodes:
# 	Node: 1400
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 2320
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 1021
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
# 	Node: 1696
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 595
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 2556
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 243
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
# 	Node: 728
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 2304
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
# 	Node: 2375
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 726
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 20
# 	Node: 2011
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 249
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 14
# 	Node: 1924
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 32
#
# Edge between nodes:
# 	Node: 946
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
# 	Node: 1461
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 21
#
# Edge between nodes:
# 	Node: 1376
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 22
# 	Node: 2070
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 1218
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 25
# 	Node: 1432
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 24
#
# Edge between nodes:
# 	Node: 662
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2584
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 1893
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 12
# 	Node: 2677
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 926
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 2171
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 400
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 5
# 	Node: 2342
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 932
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2337
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 207
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 10
# 	Node: 2540
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 2051
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 31
# 	Node: 2102
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 949
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2658
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 37
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
# 	Node: 1641
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 249
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 14
# 	Node: 2070
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 1793
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
# 	Node: 2487
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1584
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 84
# 	Node: 2500
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 667
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
# 	Node: 2565
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 2544
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 2
# 	Node: 2669
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1641
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 1642
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 200
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 343
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 78
#
# Edge between nodes:
# 	Node: 1503
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 20
# 	Node: 2642
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 16
#
# Edge between nodes:
# 	Node: 888
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 7
# 	Node: 2165
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 35
#
# Edge between nodes:
# 	Node: 1504
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 5
# 	Node: 2302
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 49
#
# [1.1102661596958174]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  527.0  | Percentage change: 9.98%
# Miss Rate:  0.09294320137693635
# ----
# Average Degree: 4.037037037037037
# Min Degree: 2.0
# Max Degree: 12.0
# Min Homophily: 0.25
# Max Homophily: 1.0
# Average Homophily: 0.8240740740740741
# Min Two-hop Neighborhood Size: 2.0
# Max Two-hop Neighborhood Size: 68.0
# Average Two-hop Neighborhood Size: 15.5
# Ground Truth Classification Counts: [9, 7, 3, 18, 10, 4, 3]
# ----
# Edge between nodes:
# 	Node: 1246
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 2253
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 401
# 		Homophily: 0.5
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
# 	Node: 1174
# 		Homophily: 0.6666666666666666
# 		Degree: 12
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 76
#
# Edge between nodes:
# 	Node: 1506
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 20
# 	Node: 2563
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1372
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 6
# 	Node: 2483
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 2318
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 16
# 	Node: 2453
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 1591
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2489
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 2341
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 2362
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 572
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 36
# 	Node: 1283
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 692
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2619
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 804
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 2208
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 23
#
# Edge between nodes:
# 	Node: 2561
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
# 	Node: 2629
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2384
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 13
# 	Node: 2552
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 642
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
# 	Node: 856
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 1547
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
# 	Node: 2431
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2011
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
# 	Node: 2372
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 24
#
# Edge between nodes:
# 	Node: 1581
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 60
# 	Node: 2006
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 257
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 17
# 	Node: 1536
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1420
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 20
# 	Node: 2067
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2036
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 50
# 	Node: 2267
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 2293
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 24
# 	Node: 2353
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2555
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2668
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1355
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
# 	Node: 2406
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 2345
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 20
# 	Node: 2533
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 2128
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 2494
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 2024
# 		Homophily: 0.3333333333333333
# 		Degree: 12
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 27
# 	Node: 2418
# 		Homophily: 0.8333333333333334
# 		Degree: 12
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 282
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 7
# 	Node: 2649
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2328
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
# 	Node: 2635
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 497
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
# 	Node: 2239
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 12
#
# Edge between nodes:
# 	Node: 378
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 856
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 2362
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
# 	Node: 2705
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2300
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
# 	Node: 2639
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 198
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
# 	Node: 2683
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 66
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 2061
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 642
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
# 	Node: 1179
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 2575
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
# 	Node: 2646
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 460
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 67
# 	Node: 1068
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 2432
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 2478
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1333
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 25
# 	Node: 1462
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 16
#
# Edge between nodes:
# 	Node: 953
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 2370
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 1696
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
# 	Node: 2660
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 54
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 11
# 	Node: 2301
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 2378
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
# 	Node: 2573
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1310
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2557
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 130
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 41
# 	Node: 1228
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 2292
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 12
# 	Node: 2634
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 266
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 16
# 	Node: 1911
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1613
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2496
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1084
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 2431
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2108
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2242
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 234
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 10
# 	Node: 1967
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 20
#
# Edge between nodes:
# 	Node: 571
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
# 	Node: 1453
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 293
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 611
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1052
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2191
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 825
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 18
# 	Node: 2061
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
#
# [1.1102661596958174, 1.1024667931688805]
# CPU times: user 1min 56s, sys: 1.96 s, total: 1min 58s
# Wall time: 1min 58s

# %% [markdown]
# # Cora_ML

# %%
dataset = Dataset(root='/tmp/Cora_ML', name='Cora_ML', device=device)
data, in_feats, h_feats, num_classes = dataset.get_data()

model = get_model('../', in_feats, h_feats, num_classes, "cora_ml", Models.GCN)
ground_truth, orig_pred = get_ground_truth(model, data, Models.GCN, testMask=True)
print(ground_truth)

labels = data.y
# Out:
# Downloading https://github.com/abojchevski/graph2gauss/raw/master/data/cora_ml.npz
# Processing...
# Done!
# 0.8430717863105175

# %%
G, x, y, train_mask, test_mask = convert_to_networkx(data)

homophilies = [0] * len(G.nodes())
degrees = [0] * len(G.nodes())
two_hop_neighborhood_sizes = [0] * len(G.nodes())

for n in G.nodes():
    homophilies[n] = get_node_homophily(G, n, y, y[n].item())
    degrees[n] = G.degree(n)
    two_hop_neighborhood_sizes[n] = nx.ego_graph(G, n, 2).number_of_nodes()

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()
print(G.number_of_nodes())
for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, G):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))
# Out:
# 2995
# 517638
# CPU times: user 9.87 s, sys: 10 ms, total: 9.88 s
# Wall time: 9.9 s

# %%
### have to store due to resetting in cora_ml
from copy import deepcopy
data = deepcopy(data)

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_ml = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    modified_graph = deepcopy(data)
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        # print(edge)
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GCN, testMask=True)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(ground_truth, test_model(model, modified_graph, GCNtype=Models.GCN, testMask=True)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_ml.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/degree/cora_ml/critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_ml)
# Out:
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  407.0  | Percentage change: 4.99%
# Miss Rate:  0.04460093896713613
# ----
# Average Degree: 5.157894736842105
# Min Degree: 2.0
# Max Degree: 24.0
# Min Homophily: 0.5
# Max Homophily: 1.0
# Average Homophily: 0.875
# Min Two-hop Neighborhood Size: 3.0
# Max Two-hop Neighborhood Size: 164.5
# Average Two-hop Neighborhood Size: 42.76315789473684
# Ground Truth Classification Counts: [1, 5, 1, 2, 5, 1, 4]
# ----
# Edge between nodes:
# 	Node: 74
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 26
# 	Node: 436
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 324
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 266
# 	Node: 598
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 63
#
# Edge between nodes:
# 	Node: 1170
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 61
# 	Node: 2619
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2246
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
# 	Node: 2846
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 840
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
# 	Node: 2477
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1617
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 24
# 	Node: 1734
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1066
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 16
# 	Node: 1182
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 35
#
# Edge between nodes:
# 	Node: 2189
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 7
# 	Node: 2477
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 2028
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 35
# 	Node: 2427
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 153
#
# Edge between nodes:
# 	Node: 1072
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 45
# 	Node: 2403
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 1172
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 35
# 	Node: 1807
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 632
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2755
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1470
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 32
# 	Node: 2823
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1591
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 16
# 	Node: 2022
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 885
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 37
# 	Node: 2786
# 		Homophily: 0.4166666666666667
# 		Degree: 24
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 126
#
# Edge between nodes:
# 	Node: 602
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 25
# 	Node: 2631
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 155
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 154
# 	Node: 2840
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1923
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
# 	Node: 2809
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 624
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 107
# 	Node: 1004
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 87
#
# [1.0466830466830468]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
# 550  iterations!
# 600  iterations!
# 650  iterations!
# 700  iterations!
# 750  iterations!
# 800  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  815.0  | Percentage change: 9.99%
# Miss Rate:  0.06750572082379858
# ----
# Average Degree: 4.203389830508475
# Min Degree: 2.0
# Max Degree: 20.0
# Min Homophily: 0.0
# Max Homophily: 1.0
# Average Homophily: 0.8080104923325263
# Min Two-hop Neighborhood Size: 2.5
# Max Two-hop Neighborhood Size: 162.0
# Average Two-hop Neighborhood Size: 36.75423728813559
# Ground Truth Classification Counts: [4, 3, 11, 11, 18, 4, 8]
# ----
# Edge between nodes:
# 	Node: 2575
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2576
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 593
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
# 	Node: 2403
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 1102
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 27
# 	Node: 2499
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 33
#
# Edge between nodes:
# 	Node: 2204
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
# 	Node: 2511
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1684
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
# 	Node: 2755
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 945
# 		Homophily: 0.7142857142857143
# 		Degree: 14
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 87
# 	Node: 1260
# 		Homophily: 0.7142857142857143
# 		Degree: 14
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 32
#
# Edge between nodes:
# 	Node: 399
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 247
# 	Node: 980
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 802
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 26
# 	Node: 2238
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 45
#
# Edge between nodes:
# 	Node: 13
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2403
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 1790
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 60
# 	Node: 2183
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 2548
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 2603
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 79
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 18
# 	Node: 1066
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 16
#
# Edge between nodes:
# 	Node: 1619
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 84
# 	Node: 1857
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2183
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
# 	Node: 2989
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 1048
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 84
# 	Node: 2732
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 16
#
# Edge between nodes:
# 	Node: 627
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1775
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 51
#
# Edge between nodes:
# 	Node: 2417
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 4
# 	Node: 2516
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2939
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2967
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 73
#
# Edge between nodes:
# 	Node: 2023
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2477
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 2403
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 77
# 	Node: 2855
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 42
#
# Edge between nodes:
# 	Node: 476
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 247
# 	Node: 1339
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 33
#
# Edge between nodes:
# 	Node: 1877
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 33
# 	Node: 2753
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1642
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
# 	Node: 2555
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1502
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
# 	Node: 2846
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1807
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
# 	Node: 2481
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 12
#
# Edge between nodes:
# 	Node: 280
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 75
# 	Node: 1406
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 40
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 11
# 	Node: 1810
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1653
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 100
# 	Node: 1857
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 639
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
# 	Node: 2628
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 16
#
# Edge between nodes:
# 	Node: 1688
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
# 	Node: 2339
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 465
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 25
# 	Node: 970
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1588
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 11
# 	Node: 2058
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1792
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 63
# 	Node: 2625
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 700
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
# 	Node: 2163
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1956
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
# 	Node: 2974
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 61
#
# Edge between nodes:
# 	Node: 65
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 243
# 	Node: 2669
# 		Homophily: 0.3
# 		Degree: 20
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 71
#
# Edge between nodes:
# 	Node: 139
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 3
# 	Node: 2986
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2085
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
# 	Node: 2844
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 90
#
# Edge between nodes:
# 	Node: 760
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 97
# 	Node: 2915
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 39
#
# Edge between nodes:
# 	Node: 1121
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 63
# 	Node: 1730
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 29
#
# Edge between nodes:
# 	Node: 1906
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
# 	Node: 2204
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 310
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 10
# 	Node: 1288
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 251
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
# 	Node: 1807
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 373
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 8
# 	Node: 2085
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1734
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 9
# 	Node: 2339
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 397
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 247
# 	Node: 1928
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 2079
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 27
# 	Node: 2246
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2130
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2381
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 826
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 104
# 	Node: 2798
# 		Homophily: 0.2
# 		Degree: 10
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 95
#
# Edge between nodes:
# 	Node: 925
# 		Homophily: 0.6
# 		Degree: 20
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 137
# 	Node: 935
# 		Homophily: 0.2
# 		Degree: 20
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 65
#
# Edge between nodes:
# 	Node: 236
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 21
# 	Node: 627
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 536
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 1715
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2573
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2859
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1258
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 4
# 	Node: 2709
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 871
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 76
# 	Node: 2846
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 417
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 23
# 	Node: 1877
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 33
#
# Edge between nodes:
# 	Node: 260
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 253
# 	Node: 792
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 48
#
# Edge between nodes:
# 	Node: 2220
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 52
# 	Node: 2487
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 52
#
# Edge between nodes:
# 	Node: 1688
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
# 	Node: 2266
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 2
#
# [1.0466830466830468, 1.0723926380368098]
# CPU times: user 4min 9s, sys: 3.37 s, total: 4min 12s
# Wall time: 4min 13s

# %% [markdown]
# # Citeseer

# %%
dataset = Dataset(root='/tmp/Citeseer', name='Citeseer', device=device)
data, in_feats, h_feats, num_classes = dataset.get_data()

model = get_model('../', in_feats, h_feats, num_classes, "citeseer", Models.GCN)
ground_truth, orig_pred = get_ground_truth(model, data, Models.GCN, testMask=True)

labels = data.y
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.test.index
# Processing...
# Done!

# %%
G, x, y, train_mask, test_mask = convert_to_networkx(data)

homophilies = [0] * len(G.nodes())
degrees = [0] * len(G.nodes())
two_hop_neighborhood_sizes = [0] * len(G.nodes())

for n in G.nodes():
    homophilies[n] = get_node_homophily(G, n, y, y[n].item())
    degrees[n] = G.degree(n)
    two_hop_neighborhood_sizes[n] = nx.ego_graph(G, n, 2).number_of_nodes()

# %%
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()
print(G.number_of_nodes())
for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, G):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))
# Out:
# 3327
# 1343829

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_citeseer = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GCN, testMask=True)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(ground_truth, test_model(model, modified_graph, GCNtype=Models.GCN, testMask=True)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_citeseer.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/degree/citeseer/critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_citeseer)
# Out:
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 200  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  227.0  | Percentage change: 4.99%
# Miss Rate:  0.13358778625954193
# ----
# Average Degree: 2.9714285714285715
# Min Degree: 2.0
# Max Degree: 14.0
# Min Homophily: 0.0
# Max Homophily: 1.0
# Average Homophily: 0.6887755102040817
# Min Two-hop Neighborhood Size: 2.0
# Max Two-hop Neighborhood Size: 68.0
# Average Two-hop Neighborhood Size: 7.385714285714286
# Ground Truth Classification Counts: [3, 9, 4, 5, 4, 10]
# ----
# Edge between nodes:
# 	Node: 2756
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
# 	Node: 2896
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1053
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
# 	Node: 2856
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 53
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
# 	Node: 3083
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1937
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 3199
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 121
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
# 	Node: 1076
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1739
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
# 	Node: 2003
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 2623
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2766
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 161
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
# 	Node: 2498
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 854
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
# 	Node: 2598
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 32
#
# Edge between nodes:
# 	Node: 1722
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
# 	Node: 2461
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 797
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
# 	Node: 2764
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1314
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2568
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 644
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 9
# 	Node: 3060
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 2197
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
# 	Node: 3199
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 2171
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
# 	Node: 2753
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1588
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
# 	Node: 1922
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 593
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 3178
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2158
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 2959
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 614
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 1643
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 3005
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
# 	Node: 3189
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 320
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 2768
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1245
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
# 	Node: 3113
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2998
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 3311
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1079
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
# 	Node: 2612
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 117
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 2
# 	Node: 3288
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 2348
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 9
# 	Node: 2649
# 		Homophily: 0.7142857142857143
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 127
#
# Edge between nodes:
# 	Node: 1418
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
# 	Node: 2661
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 1284
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
# 	Node: 3016
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 107
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 18
# 	Node: 2864
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 2893
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 6
# 	Node: 3194
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 93
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
# 	Node: 1475
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 425
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 2503
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 739
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 795
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 190
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 9
# 	Node: 2731
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1503
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
# 	Node: 2190
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# [1.1541850220264318]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  455.0  | Percentage change: 10.00%
# Miss Rate:  0.125
# ----
# Average Degree: 3.076923076923077
# Min Degree: 2.0
# Max Degree: 14.0
# Min Homophily: 0.0
# Max Homophily: 1.0
# Average Homophily: 0.7073260073260074
# Min Two-hop Neighborhood Size: 2.0
# Max Two-hop Neighborhood Size: 35.5
# Average Two-hop Neighborhood Size: 6.915384615384616
# Ground Truth Classification Counts: [1, 13, 9, 18, 12, 12]
# ----
# Edge between nodes:
# 	Node: 2109
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
# 	Node: 2327
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 666
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 6
# 	Node: 3129
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1501
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 3005
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 818
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 9
# 	Node: 2934
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 272
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
# 	Node: 1073
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 3
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 5
# 	Node: 2552
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1010
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 23
# 	Node: 2000
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 708
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 7
# 	Node: 2983
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 333
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
# 	Node: 2837
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 2865
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 3111
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 776
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 10
# 	Node: 2480
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 2327
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2971
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 617
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 3
# 	Node: 2990
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 196
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2692
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 896
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 3178
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2262
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 3183
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1163
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 8
# 	Node: 2751
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1679
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
# 	Node: 2796
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 531
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 570
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1177
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 2932
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1243
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 12
# 	Node: 2699
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1572
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 4
# 	Node: 3100
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1409
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1856
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 2908
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 3178
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1383
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 19
# 	Node: 3164
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 900
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 1511
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 382
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 1055
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2177
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 2764
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1058
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 3240
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 67
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 3239
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 950
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
# 	Node: 3235
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2669
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 6
# 	Node: 3236
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 2599
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 15
# 	Node: 3119
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 22
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
# 	Node: 1349
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2471
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 3216
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 52
#
# Edge between nodes:
# 	Node: 2383
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
# 	Node: 3224
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 2313
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 14
# 	Node: 2837
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 718
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 2870
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 893
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 2
# 	Node: 2846
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 662
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
# 	Node: 3178
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1056
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 2870
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 2012
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
# 	Node: 2546
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 966
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 15
# 	Node: 2610
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 300
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 18
# 	Node: 1523
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 613
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 5
# 	Node: 1924
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 270
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
# 	Node: 2661
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 3098
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
# 	Node: 3142
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 971
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 4
# 	Node: 3231
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 877
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
# 	Node: 2578
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 33
#
# Edge between nodes:
# 	Node: 1785
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2465
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 496
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1679
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1667
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 11
# 	Node: 2714
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 2710
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 13
# 	Node: 3164
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 846
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 18
# 	Node: 2661
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2175
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
# 	Node: 3162
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 2263
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
# 	Node: 3100
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1394
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 3
# 	Node: 3084
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 162
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
# 	Node: 3115
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 183
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 511
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 2405
# 		Homophily: 0.5714285714285714
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 27
# 	Node: 2422
# 		Homophily: 0.7142857142857143
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 44
#
# Edge between nodes:
# 	Node: 1038
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 3279
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 67
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2392
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 123
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 12
# 	Node: 1519
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 2144
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 2869
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1519
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 1892
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 2
#
# [1.1541850220264318, 1.1428571428571428]
# CPU times: user 1min 39s, sys: 1.61 s, total: 1min 40s
# Wall time: 1min 41s

# %% [markdown]
# # Data

# %%
# Plotting
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
plt.plot(ptb_rate, results_cora, label="cora")
plt.plot(ptb_rate, results_ml, label="cora_ml")
plt.plot(ptb_rate, results_citeseer, label="citeseer")

plt.xlabel('PTB Rates')
plt.ylabel('number of iterations')
plt.title('Greedy Approach w/ Correct Classifications')
plt.legend()

output_path = f"./data/degree/greedy_w_correct_classifications.png"
plt.savefig(output_path)

# Show plot
plt.show()

# %%
import os

def save_data(file_path, data):
    # Automatically create the directory if it doesn't exist
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    # Save the data to the file
    np.save(file_path, data)

# Assuming 'dataset' is a variable you have already defined
dataset_paths = [
    f'./data-arrays/degree/cora/gcn_results.npy',
    f'./data-arrays/degree/cora/pubmed/cora_ml.npy',
    f'./data-arrays/degree/cora/citeseer/gcn_results.npy',
]

results = [
    np.array(results_cora),
    np.array(results_ml),
    np.array(results_citeseer),
]

# Save each results array to its corresponding file
for path, data in zip(dataset_paths, results):
    save_data(path, data)
