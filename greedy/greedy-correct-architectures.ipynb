# %% [markdown]
# # Greedy Addition For Correct Nodes

# %%
# these warnings are fine. you can ignore them.
import random, math
from CriticalNodes import CriticalEdge, CriticalEdges
import pickle

import sys
sys.path.append('../')
from util import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Imports finished.")
# Out:
# Imports finished.

# %%
max_rate = 0.35

# %%
### realistically, this should be the only function changing in your guys' notebooks
def checkCorrectClass(i, j, pred):
    return pred[i].item() == pred[j].item() and labels[i].item() == labels[j].item() and pred[i].item() == labels[i].item() and pred[j].item() == labels[j].item()

# %% [markdown]
# ## Setting Up Dataset/Model/Ground Truth

# %%
dataset = Dataset(root='/tmp/Cora', name='Cora', device=device)
data, in_feats, h_feats, num_classes = dataset.get_data()

gcn_model = get_model('../', in_feats, h_feats, num_classes, "cora", Models.GCN)
gcn_ground_truth, gcn_orig_pred = get_ground_truth(gcn_model, data, Models.GCN, testMask=False)
print(gcn_ground_truth)

gat_model = get_model('../', in_feats, h_feats, num_classes, "cora", Models.GAT)
gat_ground_truth, gat_orig_pred = get_ground_truth(gat_model, data, Models.GAT, testMask=False)
print(gat_ground_truth)

gsage_model = get_model('../', in_feats, h_feats, num_classes, "cora", Models.GSAGE)
gsage_ground_truth, gsage_orig_pred = get_ground_truth(gsage_model, data, Models.GSAGE, testMask=False)
print(gsage_ground_truth)

gsaint_model = get_model('../', in_feats, h_feats, num_classes, "cora", Models.GSAINT, data=dataset)
gsaint_ground_truth, gsaint_orig_pred = get_ground_truth(gsaint_model, data, Models.GSAINT, testMask=False)
print(gsaint_ground_truth)
# Out:
# 0.7544313146233382
# 0.7518463810930576
# 0.5384047267355982
# 0.7699409158050221

# %%
labels = data.y

# %% [markdown]
# ## Experiments

# %% [markdown]
# **Note:** The ground truth here is $0.745$

# %%
G, x, y, train_mask, test_mask = convert_to_networkx(data)

homophilies = [0] * len(G.nodes())
degrees = [0] * len(G.nodes())
two_hop_neighborhood_sizes = [0] * len(G.nodes())

for n in G.nodes():
    homophilies[n] = get_node_homophily(G, n, y, y[n].item())
    degrees[n] = G.degree(n)
    two_hop_neighborhood_sizes[n] = nx.ego_graph(G, n, 2).number_of_nodes()

# %% [markdown]
# ### GCN

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()

for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, gcn_orig_pred):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))
# Out:
# 348735
# CPU times: user 4min 46s, sys: 27.5 s, total: 5min 14s
# Wall time: 5min 12s

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_gcn = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(gcn_model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GCN, testMask=False)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - gcn_ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(gcn_ground_truth, test_model(gcn_model, modified_graph, GCNtype=Models.GCN, testMask=False)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_gcn.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/correct-archs/gcn/critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_gcn)
# Out:
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  263.0  | Percentage change: 4.98%
# Miss Rate:  0.025925925925925908
# ----
# Average Degree: 7.142857142857143
# Min Degree: 4.0
# Max Degree: 14.0
# Min Homophily: 0.7142857142857143
# Max Homophily: 1.0
# Average Homophily: 0.923469387755102
# Min Two-hop Neighborhood Size: 22.5
# Max Two-hop Neighborhood Size: 99.5
# Average Two-hop Neighborhood Size: 50.785714285714285
# Ground Truth Classification Counts: [1, 0, 1, 4, 1]
# ----
# Edge between nodes:
# 	Node: 1023
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 131
# 	Node: 1988
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
#
# Edge between nodes:
# 	Node: 1020
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 29
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 1808
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 51
# 	Node: 2566
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1203
# 		Homophily: 0.42857142857142855
# 		Degree: 14
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 41
# 	Node: 2202
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 21
#
# Edge between nodes:
# 	Node: 2121
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 32
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 316
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 49
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
# 	Node: 977
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
#
# [1.026615969581749]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  527.0  | Percentage change: 9.98%
# Miss Rate:  0.041818181818181865
# ----
# Average Degree: 11.695652173913043
# Min Degree: 4.0
# Max Degree: 69.0
# Min Homophily: 0.625
# Max Homophily: 1.0
# Average Homophily: 0.9307438937873719
# Min Two-hop Neighborhood Size: 4.5
# Max Two-hop Neighborhood Size: 129.0
# Average Two-hop Neighborhood Size: 30.065217391304348
# Ground Truth Classification Counts: [0, 0, 2, 13, 3, 2, 3]
# ----
# Edge between nodes:
# 	Node: 565
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 42
# 	Node: 2421
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1184
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
# 	Node: 1962
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 7
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2303
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 36
#
# Edge between nodes:
# 	Node: 448
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 26
# 	Node: 1184
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 893
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 25
# 	Node: 1063
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 1192
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 34
# 	Node: 2571
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 445
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1457
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 232
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 136
# 	Node: 1810
# 		Homophily: 0.9090909090909091
# 		Degree: 88
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 122
#
# Edge between nodes:
# 	Node: 1986
# 		Homophily: 0.7384615384615385
# 		Degree: 130
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 195
# 	Node: 2177
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 23
#
# Edge between nodes:
# 	Node: 307
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 2
# 	Node: 2395
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 223
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 19
# 	Node: 1706
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 295
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 2006
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 570
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
# 	Node: 1290
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 2147
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 2245
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1157
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 32
# 	Node: 2383
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1815
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 65
#
# Edge between nodes:
# 	Node: 27
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 53
# 	Node: 374
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 2228
# 		Homophily: 0.6666666666666666
# 		Degree: 12
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 32
# 	Node: 2461
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 374
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
# 	Node: 2343
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 299
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 22
# 	Node: 789
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 23
#
# Edge between nodes:
# 	Node: 1192
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 34
# 	Node: 1994
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
#
# Edge between nodes:
# 	Node: 1396
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 25
# 	Node: 2608
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 386
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 1348
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 61
#
# [1.026615969581749, 1.0436432637571158]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
# 550  iterations!
# 600  iterations!
# 600  iterations!
# 650  iterations!
# 700  iterations!
# 750  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  791.0  | Percentage change: 14.99%
# Miss Rate:  0.08130081300813008
# ----
# Average Degree: 6.742857142857143
# Min Degree: 2.0
# Max Degree: 36.0
# Min Homophily: 0.3333333333333333
# Max Homophily: 1.0
# Average Homophily: 0.904071583178726
# Min Two-hop Neighborhood Size: 4.5
# Max Two-hop Neighborhood Size: 185.0
# Average Two-hop Neighborhood Size: 45.67142857142857
# Ground Truth Classification Counts: [2, 1, 7, 45, 12, 1, 2]
# ----
# Edge between nodes:
# 	Node: 358
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
#
# Edge between nodes:
# 	Node: 2395
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 26
# 	Node: 2396
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1175
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2613
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 649
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 1813
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 47
#
# Edge between nodes:
# 	Node: 788
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
# 	Node: 2536
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 2215
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 16
# 	Node: 2667
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 2303
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 36
#
# Edge between nodes:
# 	Node: 430
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
# 	Node: 2352
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 114
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 9
# 	Node: 2553
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 1064
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
# 	Node: 1491
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 11
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 17
# 	Node: 1174
# 		Homophily: 0.6666666666666666
# 		Degree: 12
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 76
#
# Edge between nodes:
# 	Node: 202
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 8
# 	Node: 326
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
#
# Edge between nodes:
# 	Node: 894
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 396
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 2213
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 2190
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 13
# 	Node: 2394
# 		Homophily: 0.875
# 		Degree: 32
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 62
#
# Edge between nodes:
# 	Node: 1418
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2661
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1219
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2636
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 727
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1820
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 119
#
# Edge between nodes:
# 	Node: 1777
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 67
# 	Node: 2325
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 1410
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
# 	Node: 2575
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 633
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 77
# 	Node: 2495
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 78
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
# 	Node: 2680
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 288
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 874
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 205
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 83
# 	Node: 746
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 226
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 1363
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 73
# 		Homophily: 0.9166666666666666
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 196
# 	Node: 1205
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
#
# Edge between nodes:
# 	Node: 1390
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
# 	Node: 2637
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 158
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 124
# 	Node: 261
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 92
#
# Edge between nodes:
# 	Node: 1016
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1241
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 96
#
# Edge between nodes:
# 	Node: 209
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 2261
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 1201
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1219
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1063
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
# 	Node: 2564
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 336
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 532
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 874
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2706
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 4
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
# 	Node: 1987
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 394
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 15
# 	Node: 2417
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 944
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1323
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 1212
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1863
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2513
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1052
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2216
# 		Homophily: 0.8571428571428571
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 215
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 155
# 	Node: 598
# 		Homophily: 0.8787878787878788
# 		Degree: 66
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 95
#
# Edge between nodes:
# 	Node: 261
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 92
# 	Node: 1876
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 1869
# 		Homophily: 0.5
# 		Degree: 20
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 143
# 	Node: 2599
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 869
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 98
# 	Node: 1934
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 20
#
# Edge between nodes:
# 	Node: 1390
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
# 	Node: 1702
# 		Homophily: 0.9
# 		Degree: 20
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 39
#
# Edge between nodes:
# 	Node: 1818
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 79
# 	Node: 1859
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 319
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 351
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
#
# Edge between nodes:
# 	Node: 13
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 116
# 	Node: 972
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 1867
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 84
# 	Node: 2403
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 205
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 83
# 	Node: 486
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1859
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 2230
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 1546
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 187
# 	Node: 1762
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 171
#
# Edge between nodes:
# 	Node: 1864
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 98
# 	Node: 1944
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 24
#
# Edge between nodes:
# 	Node: 1613
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 1853
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 500
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1867
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 84
#
# Edge between nodes:
# 	Node: 1582
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 2317
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 12
#
# Edge between nodes:
# 	Node: 874
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 1942
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 37
#
# Edge between nodes:
# 	Node: 330
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 21
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 209
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 6
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1075
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 78
# 	Node: 1453
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 1201
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1861
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 1091
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 2317
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 12
#
# Edge between nodes:
# 	Node: 105
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 22
# 	Node: 1205
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
#
# Edge between nodes:
# 	Node: 633
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 77
# 	Node: 2138
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 40
#
# Edge between nodes:
# 	Node: 1636
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 102
# 	Node: 1662
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
# 	Node: 2241
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 2519
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 2636
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 156
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
# 	Node: 565
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 42
#
# Edge between nodes:
# 	Node: 1589
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 11
# 	Node: 2451
# 		Homophily: 0.9090909090909091
# 		Degree: 22
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 26
#
# [1.026615969581749, 1.0436432637571158, 1.0884955752212389]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
# 550  iterations!
# 600  iterations!
# 650  iterations!
# 700  iterations!
# 750  iterations!
# 800  iterations!
# 850  iterations!
# 900  iterations!
# 950  iterations!
# 1000  iterations!
# 1000  iterations!
# 1050  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  1055.0  | Percentage change: 19.99%
# Miss Rate:  0.0786026200873362
# ----
# Average Degree: 8.244444444444444
# Min Degree: 2.0
# Max Degree: 67.0
# Min Homophily: 0.375
# Max Homophily: 1.0
# Average Homophily: 0.8961343903010569
# Min Two-hop Neighborhood Size: 5.0
# Max Two-hop Neighborhood Size: 201.5
# Average Two-hop Neighborhood Size: 48.394444444444446
# Ground Truth Classification Counts: [7, 2, 15, 52, 11, 0, 3]
# ----
# Edge between nodes:
# 	Node: 914
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 2570
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1453
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 1877
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 2054
# 		Homophily: 1.0
# 		Degree: 18
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 78
# 	Node: 2171
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 210
# 		Homophily: 0.5
# 		Degree: 20
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 45
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1279
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 13
# 	Node: 1410
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 2398
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 298
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 2570
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1099
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
# 	Node: 1813
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 47
#
# Edge between nodes:
# 	Node: 275
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
# 	Node: 1129
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 568
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 47
# 	Node: 1636
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 102
#
# Edge between nodes:
# 	Node: 877
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 39
# 	Node: 994
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 1671
# 		Homophily: 0.3333333333333333
# 		Degree: 12
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 24
# 	Node: 2563
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 1426
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
# 	Node: 1466
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 991
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 2
# 	Node: 2228
# 		Homophily: 0.6666666666666666
# 		Degree: 12
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 32
#
# Edge between nodes:
# 	Node: 2136
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
# 	Node: 2312
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 1410
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
# 	Node: 2499
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 2147
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 2308
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 230
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 64
# 	Node: 1176
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 40
#
# Edge between nodes:
# 	Node: 497
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 5
# 	Node: 1110
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 44
#
# Edge between nodes:
# 	Node: 649
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 1090
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
#
# Edge between nodes:
# 	Node: 79
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 12
# 	Node: 1923
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 30
#
# Edge between nodes:
# 	Node: 1124
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
# 	Node: 1175
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 2046
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 101
# 	Node: 2325
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 216
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 104
# 	Node: 2247
# 		Homophily: 0.8571428571428571
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 232
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 136
# 	Node: 972
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
#
# Edge between nodes:
# 	Node: 795
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 54
# 	Node: 1853
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 42
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 6
# 	Node: 2395
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 547
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 97
# 	Node: 1348
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 61
#
# Edge between nodes:
# 	Node: 1399
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 36
# 	Node: 1593
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 6
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 158
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 124
# 	Node: 1272
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 23
#
# Edge between nodes:
# 	Node: 48
# 		Homophily: 0.8888888888888888
# 		Degree: 18
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 55
# 	Node: 216
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 104
#
# Edge between nodes:
# 	Node: 1091
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1866
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 76
#
# Edge between nodes:
# 	Node: 269
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 12
# 	Node: 2539
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1075
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 78
# 	Node: 2599
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 321
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 547
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 97
#
# Edge between nodes:
# 	Node: 813
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
# 	Node: 1194
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 12
#
# Edge between nodes:
# 	Node: 1000
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
# 	Node: 1290
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 445
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1820
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 119
#
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1392
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 10
#
# Edge between nodes:
# 	Node: 1171
# 		Homophily: 0.7
# 		Degree: 20
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
# 	Node: 1871
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 93
#
# Edge between nodes:
# 	Node: 532
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 981
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1445
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 1877
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 77
#
# Edge between nodes:
# 	Node: 1418
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 4
# 	Node: 2352
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 201
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 157
# 	Node: 261
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 92
#
# Edge between nodes:
# 	Node: 1323
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2626
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1303
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 40
# 	Node: 1865
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 85
#
# Edge between nodes:
# 	Node: 869
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 98
# 	Node: 1147
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
#
# Edge between nodes:
# 	Node: 19
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
# 	Node: 1859
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 1271
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
# 	Node: 1479
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 92
#
# Edge between nodes:
# 	Node: 1241
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 96
# 	Node: 2077
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
#
# Edge between nodes:
# 	Node: 1177
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 32
# 	Node: 1875
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 150
#
# Edge between nodes:
# 	Node: 649
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 1986
# 		Homophily: 0.7384615384615385
# 		Degree: 130
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 195
#
# Edge between nodes:
# 	Node: 1294
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 33
# 	Node: 1299
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 135
#
# Edge between nodes:
# 	Node: 1290
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
# 	Node: 2305
# 		Homophily: 0.6666666666666666
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1546
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 187
# 	Node: 2657
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 4
#
# Edge between nodes:
# 	Node: 1988
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 456
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 55
# 	Node: 2171
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 1101
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1175
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
# 	Node: 1706
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1390
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
# 	Node: 2435
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 223
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 19
# 	Node: 466
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 176
#
# Edge between nodes:
# 	Node: 357
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 184
# 	Node: 687
# 		Homophily: 0.9333333333333333
# 		Degree: 30
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 219
#
# Edge between nodes:
# 	Node: 1209
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 172
# 	Node: 2359
# 		Homophily: 0.7272727272727273
# 		Degree: 22
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 45
#
# Edge between nodes:
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
# 	Node: 1389
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 172
#
# Edge between nodes:
# 	Node: 1742
# 		Homophily: 1.0
# 		Degree: 30
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 198
# 	Node: 2451
# 		Homophily: 0.9090909090909091
# 		Degree: 22
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 1251
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 114
# 	Node: 2584
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 1
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 453
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 994
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 534
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 14
# 	Node: 565
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 42
#
# Edge between nodes:
# 	Node: 148
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
# 	Node: 243
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 230
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 64
# 	Node: 1868
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 90
#
# Edge between nodes:
# 	Node: 1994
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
# 	Node: 2539
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1815
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 65
# 	Node: 2519
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 649
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 2205
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 19
#
# Edge between nodes:
# 	Node: 1178
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 15
# 	Node: 2354
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1664
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 2304
# 		Homophily: 0.25
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
#
# Edge between nodes:
# 	Node: 1103
# 		Homophily: 1.0
# 		Degree: 34
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 188
# 	Node: 1989
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 67
#
# Edge between nodes:
# 	Node: 71
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 68
# 	Node: 1155
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 18
#
# Edge between nodes:
# 	Node: 1295
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 15
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 1610
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 35
# 	Node: 1715
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
#
# Edge between nodes:
# 	Node: 575
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 2539
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 595
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1996
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 390
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
# 	Node: 2006
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 577
# 		Homophily: 0.8333333333333334
# 		Degree: 24
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 21
# 	Node: 2262
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 511
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 46
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 2447
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
# 	Node: 2560
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 1383
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 8
# 	Node: 1711
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 176
#
# Edge between nodes:
# 	Node: 856
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 17
# 	Node: 2684
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 337
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 181
# 	Node: 464
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 421
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1457
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 86
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 65
# 	Node: 2387
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 24
#
# [1.026615969581749, 1.0436432637571158, 1.0884955752212389, 1.085308056872038]
# 0  iterations!
# 50  iterations!
# 100  iterations!
# 150  iterations!
# 200  iterations!
# 250  iterations!
# 300  iterations!
# 350  iterations!
# 400  iterations!
# 450  iterations!
# 500  iterations!
# 550  iterations!
# 600  iterations!
# 650  iterations!
# 700  iterations!
# 750  iterations!
# 750  iterations!
# 800  iterations!
# 850  iterations!
# 900  iterations!
# 950  iterations!
# 1000  iterations!
# 1050  iterations!
# 1100  iterations!
# 1150  iterations!
# 1200  iterations!
# 1250  iterations!
# 1300  iterations!
#
# ----
# The accuracy has not changed.
# Change in edges:  1319.0  | Percentage change: 24.99%
# Miss Rate:  0.0704721634954193
# ----
# Average Degree: 8.42
# Min Degree: 2.0
# Max Degree: 66.0
# Min Homophily: 0.36923076923076925
# Max Homophily: 1.0
# Average Homophily: 0.8924415649709768
# Min Two-hop Neighborhood Size: 3.5
# Max Two-hop Neighborhood Size: 178.5
# Average Two-hop Neighborhood Size: 47.235
# Ground Truth Classification Counts: [13, 3, 9, 65, 7, 3]
# ----
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1933
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 1382
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 35
# 	Node: 1457
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1952
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
# 	Node: 2066
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 565
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 42
# 	Node: 1339
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
#
# Edge between nodes:
# 	Node: 349
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 10
# 	Node: 1184
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
# 	Node: 1762
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 171
#
# Edge between nodes:
# 	Node: 324
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 14
# 	Node: 2051
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 1458
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
# 	Node: 1993
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 70
#
# Edge between nodes:
# 	Node: 202
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 8
# 	Node: 536
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 1710
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 187
# 	Node: 1887
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 19
#
# Edge between nodes:
# 	Node: 1945
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 21
# 	Node: 2486
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 28
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
# 	Node: 1710
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 187
#
# Edge between nodes:
# 	Node: 60
# 		Homophily: 0.3333333333333333
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 24
# 	Node: 2025
# 		Homophily: 0.5
# 		Degree: 24
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 42
#
# Edge between nodes:
# 	Node: 1201
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1947
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 23
#
# Edge between nodes:
# 	Node: 21
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 1812
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 153
#
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 2283
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 812
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 41
# 	Node: 1440
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 76
#
# Edge between nodes:
# 	Node: 1542
# 		Homophily: 0.9333333333333333
# 		Degree: 60
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 62
# 	Node: 1860
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
#
# Edge between nodes:
# 	Node: 158
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 124
# 	Node: 297
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 72
#
# Edge between nodes:
# 	Node: 569
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
# 	Node: 1426
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 235
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2605
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 157
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 102
# 	Node: 171
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1872
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 2163
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 22
#
# Edge between nodes:
# 	Node: 942
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 14
# 	Node: 1867
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 84
#
# Edge between nodes:
# 	Node: 1031
# 		Homophily: 1.0
# 		Degree: 6
# ...
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
# 	Node: 2008
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 94
#
# Edge between nodes:
# 	Node: 1876
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 2315
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 616
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 180
# 	Node: 1629
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 532
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 75
# 	Node: 1875
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 150
#
# Edge between nodes:
# 	Node: 57
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
# 	Node: 1386
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 156
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
# 	Node: 535
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 299
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 22
# 	Node: 1234
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 27
#
# Edge between nodes:
# 	Node: 1876
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 2693
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 3
#
# Edge between nodes:
# 	Node: 90
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
# 	Node: 1754
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
#
# Edge between nodes:
# 	Node: 1095
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 119
# 	Node: 1356
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 1030
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
# 	Node: 1426
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 1568
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 177
# 	Node: 1706
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
#
# Edge between nodes:
# 	Node: 341
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 203
# 	Node: 1568
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 177
#
# Edge between nodes:
# 	Node: 985
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 182
# 	Node: 2597
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 178
#
# Edge between nodes:
# 	Node: 900
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 4
# 	Node: 1192
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 34
#
# Edge between nodes:
# 	Node: 221
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 9
# 	Node: 748
# 		Homophily: 0.7272727272727273
# 		Degree: 22
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 195
#
# Edge between nodes:
# 	Node: 333
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
# 	Node: 1492
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 173
#
# Edge between nodes:
# 	Node: 561
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 6
# 	Node: 1704
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 86
#
# Edge between nodes:
# 	Node: 970
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 181
# 	Node: 1711
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 176
#
# Edge between nodes:
# 	Node: 1214
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 27
# 	Node: 1758
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 184
#
# Edge between nodes:
# 	Node: 754
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
# 	Node: 1281
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 171
#
# Edge between nodes:
# 	Node: 946
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
# 	Node: 1532
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 11
#
# Edge between nodes:
# 	Node: 158
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 124
# 	Node: 1994
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 68
#
# Edge between nodes:
# 	Node: 1095
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 119
# 	Node: 2008
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 94
#
# Edge between nodes:
# 	Node: 335
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 549
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 49
#
# Edge between nodes:
# 	Node: 859
# 		Homophily: 0.6
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 27
# 	Node: 1205
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 174
#
# Edge between nodes:
# 	Node: 83
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
# 	Node: 1566
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 25
#
# Edge between nodes:
# 	Node: 335
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
# 	Node: 622
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 2008
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 94
# 	Node: 2686
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 657
# 		Homophily: 1.0
# 		Degree: 24
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 44
# 	Node: 1604
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 173
#
# Edge between nodes:
# 	Node: 1229
# 		Homophily: 1.0
# 		Degree: 30
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 191
# 	Node: 1716
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 179
#
# Edge between nodes:
# 	Node: 1566
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 25
# 	Node: 1729
# 		Homophily: 0.8
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 213
#
# Edge between nodes:
# 	Node: 1046
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 20
# 	Node: 1129
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 393
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
# 	Node: 1184
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 5
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 1145
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 180
# 	Node: 2451
# 		Homophily: 0.9090909090909091
# 		Degree: 22
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 26
#
# Edge between nodes:
# 	Node: 796
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 182
# 	Node: 1263
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 2
#
# Edge between nodes:
# 	Node: 289
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 202
# 	Node: 1250
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 17
#
# Edge between nodes:
# 	Node: 902
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 172
# 	Node: 1612
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1719
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 183
# 	Node: 1720
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 183
#
# Edge between nodes:
# 	Node: 951
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 172
# 	Node: 2460
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 609
# 		Homophily: 1.0
# 		Degree: 16
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 188
# 	Node: 1760
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 175
#
# Edge between nodes:
# 	Node: 533
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 19
# 	Node: 853
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 176
#
# Edge between nodes:
# 	Node: 481
# 		Homophily: 0.5
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 62
# 	Node: 2597
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 178
#
# Edge between nodes:
# 	Node: 884
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 15
# 	Node: 1063
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 1238
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
# 	Node: 1730
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
#
# Edge between nodes:
# 	Node: 357
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 184
# 	Node: 358
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 5
#
# Edge between nodes:
# 	Node: 1457
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 2008
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 94
#
# Edge between nodes:
# 	Node: 1765
# 		Homophily: 1.0
# 		Degree: 34
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 185
# 	Node: 1990
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 66
#
# Edge between nodes:
# 	Node: 1748
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 176
# 	Node: 2460
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 1752
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
# 	Node: 2446
# 		Homophily: 1.0
# 		Degree: 16
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 25
#
# Edge between nodes:
# 	Node: 71
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 68
# 	Node: 1339
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
#
# Edge between nodes:
# 	Node: 326
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 170
# 	Node: 1145
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 180
#
# Edge between nodes:
# 	Node: 1517
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 29
# 	Node: 2131
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 28
#
# Edge between nodes:
# 	Node: 1989
# 		Homophily: 0.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 67
# 	Node: 2581
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 1573
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 36
# 	Node: 2247
# 		Homophily: 0.8571428571428571
# 		Degree: 14
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 297
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 72
# 	Node: 1665
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 121
#
# Edge between nodes:
# 	Node: 351
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 45
# 	Node: 1166
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 69
#
# Edge between nodes:
# 	Node: 391
# 		Homophily: 0.75
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 76
# 	Node: 1745
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 184
#
# Edge between nodes:
# 	Node: 485
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 31
# 	Node: 1913
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 13
#
# Edge between nodes:
# 	Node: 352
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 21
# 	Node: 766
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 40
#
# Edge between nodes:
# 	Node: 273
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
# 	Node: 2707
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 36
#
# Edge between nodes:
# 	Node: 1631
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 13
# 	Node: 2137
# 		Homophily: 0.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 14
#
# Edge between nodes:
# 	Node: 624
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 26
# 	Node: 2201
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 31
#
# Edge between nodes:
# 	Node: 316
# 		Homophily: 1.0
# 		Degree: 20
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 49
# 	Node: 352
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 21
#
# Edge between nodes:
# 	Node: 22
# 		Homophily: 1.0
# 		Degree: 10
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 33
# 	Node: 1390
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 8
#
# Edge between nodes:
# 	Node: 267
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 8
# 	Node: 1823
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 76
#
# Edge between nodes:
# 	Node: 760
# 		Homophily: 0.8333333333333334
# 		Degree: 12
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 21
# 	Node: 1038
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 186
#
# Edge between nodes:
# 	Node: 21
# 		Homophily: 0.5
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 5
# 	Node: 1095
# 		Homophily: 1.0
# 		Degree: 12
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 119
#
# Edge between nodes:
# 	Node: 1063
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 14
# 	Node: 2222
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 1061
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 15
# 	Node: 1064
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 4
# 		Two-hop Neighborhood Size: 9
#
# Edge between nodes:
# 	Node: 321
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 11
# 	Node: 1453
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 130
#
# Edge between nodes:
# 	Node: 1030
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 6
# 	Node: 1990
# 		Homophily: 0.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 66
#
# Edge between nodes:
# 	Node: 1610
# 		Homophily: 1.0
# 		Degree: 14
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 35
# 	Node: 2643
# 		Homophily: 1.0
# 		Degree: 2
# 		Ground Truth: 2
# 		Two-hop Neighborhood Size: 7
#
# Edge between nodes:
# 	Node: 6
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 44
# 	Node: 1540
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 29
#
# Edge between nodes:
# 	Node: 395
# 		Homophily: 1.0
# 		Degree: 6
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 18
# 	Node: 1166
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 3
# 		Two-hop Neighborhood Size: 69
#
# Edge between nodes:
# 	Node: 619
# 		Homophily: 1.0
# 		Degree: 4
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 20
# 	Node: 1925
# 		Homophily: 0.6666666666666666
# 		Degree: 6
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 39
#
# Edge between nodes:
# 	Node: 1118
# 		Homophily: 1.0
# 		Degree: 8
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 56
# 	Node: 2356
# 		Homophily: 0.2
# 		Degree: 10
# 		Ground Truth: 0
# 		Two-hop Neighborhood Size: 10
#
# [1.026615969581749, 1.0436432637571158, 1.0884955752212389, 1.085308056872038, 1.0758150113722518, 1.0934933670246367]
# CPU times: user 7min 48s, sys: 12 s, total: 8min
# Wall time: 8min 2s

# %% [markdown]
# ### GAT

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()

for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, gat_orig_pred):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_gat = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(gat_model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GAT, testMask=False)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - gat_ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(gat_ground_truth, test_model(gat_model, modified_graph, GCNtype=Models.GAT, testMask=False)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_gat.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/correct-archs/gat/median_critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_gat)

# %% [markdown]
# ### GSAINT

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()

for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, gsaint_orig_pred):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_gsaint = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(gsaint_model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GSAINT, testMask=False)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - gsaint_ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(gsaint_ground_truth, test_model(gsaint_model, modified_graph, GCNtype=Models.GSAINT, testMask=False)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_gsaint.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/correct-archs/gsaint/median_critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_gsaint)

# %% [markdown]
# ### GSAGE

# %%
# %%time
# this will take a while to run (maybe about 5-10 minutes)
valid_adds = []
tuples = set()

for i in G.nodes:
    for j in G.nodes:
        # make sure not same node and that edge doesn't already exist (also check same classification! not same label)
        if i != j and not G.has_edge(i, j) and (j, i) not in tuples and checkCorrectClass(i, j, gsage_orig_pred):
            valid_adds.append((i, j))
            tuples.add((i, j))
print(len(valid_adds))

# %%
# %%time
# if this doesn't immediately print out (0 iterations!), please re-run JUST THIS CELL, it is likely just hanging
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
change = 0.000
results_gsage = []
for ptb in ptb_rate:
    critical_edges = []
    
    random.shuffle(valid_adds)
    data = dataset.get_data()[0]
    modified_graph = data
    
    init_edges = len(modified_graph.edge_index[1])
    
    G, x, y, train_mask, test_mask = convert_to_networkx(modified_graph)

    budget = math.floor(ptb * G.number_of_edges() * 1/2)
    added = 0
    loc = 0

    while added < budget and loc < len(valid_adds):
        if added % 50 == 0:
            print(added, " iterations!")
   
        new_G = G.copy()
        
        # add edge
        edge = valid_adds[loc]
        add_edge(new_G, edge[0], edge[1], undirected=True)

        # check accuracy
        acc, pred = test_model(gsage_model, convert_to_pyg(new_G, x, y, train_mask, test_mask), GCNtype=Models.GSAGE, testMask=False)
        
        # if accuracy is still below threshold, swap graphs and add
        if abs(acc - gsage_ground_truth) <= change:
            G = new_G
            added += 1
        else:
            critical_edges.append(CriticalEdge(edge[0], edge[1], homophilies, degrees, labels, two_hop_neighborhood_sizes))

        loc += 1
    
    modified_graph = convert_to_pyg(G, x, y, train_mask, test_mask)
    final_edges = len(modified_graph.edge_index[1])
        
    output_accuracy_change(gsage_ground_truth, test_model(gsage_model, modified_graph, GCNtype=Models.GSAGE, testMask=False)[0]) 
    number_added_edges(init_edges, final_edges, is_undirected=True)
    print('Miss Rate: ', 1 - (budget / loc))
    results_gsage.append(loc / budget)

    complete_edges = CriticalEdges(critical_edges)
    complete_edges.print_statistics()
    with open(f'./critical-edges/correct-archs/gsage/median_critical_edges_{ptb}.pkl', 'wb') as file:
        pickle.dump(complete_edges, file)
    
    print(results_gsage)

# %% [markdown]
# # Data

# %%
# Plotting
ptb_rate = [(i+1) * 0.05 for i in range(int(max_rate / 0.05))]
plt.plot(ptb_rate, results_gcn, label="gcn")
plt.plot(ptb_rate, results_gat, label="gat")
plt.plot(ptb_rate, results_gsage, label="gsage")
plt.plot(ptb_rate, results_gsaint, label="gsaint")

plt.xlabel('PTB Rates')
plt.ylabel('attempts per insert')
plt.title('Greedy Approach w/ Correct Classifications')
plt.legend()

output_path = f"./data/correct-archs/greedy_archs_w_correct_classifications.png"
plt.savefig(output_path)

# Show plot
plt.show()

# %%
import os

def save_data(file_path, data):
    # Automatically create the directory if it doesn't exist
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    # Save the data to the file
    np.save(file_path, data)

# Assuming 'dataset' is a variable you have already defined
dataset_paths = [
    f'./data-arrays/correct-archs/gcn/gcn_results.npy',
    f'./data-arrays/correct-archs/gat/gat_results.npy',
    f'./data-arrays/correct-archs/gsaint/gsaint_results.npy',
    f'./data-arrays/correct-archs/gsage/gsage_results.npy',
]

results = [
    np.array(results_gcn),
    np.array(results_gat),
    np.array(results_gsaint),
    np.array(results_gsage),
]

# Save each results array to its corresponding file
for path, data in zip(dataset_paths, results):
    save_data(path, data)
