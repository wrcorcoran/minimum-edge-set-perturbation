# %% [markdown]
# # CORA (Basic Model)
# ### 2-layer GCN

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# /home/wcorcoran/anaconda3/envs/mesp/lib/python3.8/site-packages/torch_geometric/typing.py:47: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /lib64/libm.so.6: version `GLIBC_2.27' not found (required by /home/wcorcoran/anaconda3/envs/mesp/lib/python3.8/site-packages/libpyg.so)
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/wcorcoran/anaconda3/envs/mesp/lib/python3.8/site-packages/torch_geometric/typing.py:101: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /lib64/libm.so.6: version `GLIBC_2.27' not found (required by /home/wcorcoran/anaconda3/envs/mesp/lib/python3.8/site-packages/libpyg.so)
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %% [markdown]
# The following is implemented using Danish's GCN model which he sent us earlier in the quarter.

# %%
# Define the GCN model
class GCN(nn.Module):
    def __init__(self, in_feats, h_feats, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_feats, h_feats)
        self.conv2 = GCNConv(h_feats, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        h = self.conv1(x, edge_index)
        h = F.relu(h)
        h = self.conv2(h, edge_index)
        return h

# Load the datasets
cora_dataset = Planetoid(root='/tmp/Cora', name='Cora')
data = cora_dataset[0]
data = data.to(device)

# %%
in_feats = data.x.shape[1]
h_feats = 64
num_classes = cora_dataset.num_classes
model = GCN(in_feats, h_feats, num_classes)
model = model.to(device)

def train(model, data, train_mask, labels):
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    model.train()
    logits = model(data.cuda())
    
    loss = F.cross_entropy(logits[train_mask], labels[train_mask])
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return loss.item()

# %% [markdown]
# ### Uncomment the following cell if you want to save embeddings (Wyatt will likely do this, not sure - not my topic)

# %%
# def save_embeddings_and_edges(dataset, dataset_name):
#     model.eval()
#     with torch.no_grad():
#         embeddings = model(g, features)
#     print(embeddings.shape)
#     np.save(f'../embeddings/{dataset_name}_embeddings.npy', embeddings.detach().numpy())


#     edge_index = g.edges()
#     np.save(f'../embeddings/{dataset_name}_edge_index.npy', np.vstack((edge_index[0].numpy(), edge_index[1].numpy())))

# %%
train(model, data, data.train_mask, data.y)
# save_embeddings_and_edges(cora_dataset, 'cora')
# Out:
# 1.9520429372787476

# %%
def test():
    # data = cora_dataset[0].to(device)
    model.eval()
    out = model(data)
    pred = out.argmax(dim=1)

    # incorrect_indices = (pred[data.test_mask] != data.y[data.test_mask]).nonzero()

    # print("Incorrect Predictions Indices:", incorrect_indices.flatten().tolist())

    acc = (pred[data.test_mask] == data.y[data.test_mask]).sum().item() / data.test_mask.sum().item()
    return acc

for epoch in range(0, 200):
    loss = train(model, data, data.train_mask, data.y)
    acc = test()
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Accuracy: {acc:.4f}')
# Out:
# Epoch: 000, Loss: 1.6675, Accuracy: 0.7710
# Epoch: 001, Loss: 1.2989, Accuracy: 0.7700
# Epoch: 002, Loss: 0.9228, Accuracy: 0.8100
# Epoch: 003, Loss: 0.6364, Accuracy: 0.7260
# Epoch: 004, Loss: 0.4531, Accuracy: 0.8070
# Epoch: 005, Loss: 0.3454, Accuracy: 0.7190
# Epoch: 006, Loss: 0.2493, Accuracy: 0.8050
# Epoch: 007, Loss: 0.2012, Accuracy: 0.7330
# Epoch: 008, Loss: 0.1447, Accuracy: 0.8000
# Epoch: 009, Loss: 0.1277, Accuracy: 0.7510
# Epoch: 010, Loss: 0.0936, Accuracy: 0.7960
# Epoch: 011, Loss: 0.0875, Accuracy: 0.7550
# Epoch: 012, Loss: 0.0656, Accuracy: 0.7910
# Epoch: 013, Loss: 0.0631, Accuracy: 0.7550
# Epoch: 014, Loss: 0.0486, Accuracy: 0.7920
# Epoch: 015, Loss: 0.0476, Accuracy: 0.7620
# Epoch: 016, Loss: 0.0372, Accuracy: 0.7940
# Epoch: 017, Loss: 0.0370, Accuracy: 0.7610
# Epoch: 018, Loss: 0.0291, Accuracy: 0.7950
# Epoch: 019, Loss: 0.0292, Accuracy: 0.7690
# Epoch: 020, Loss: 0.0232, Accuracy: 0.7980
# Epoch: 021, Loss: 0.0234, Accuracy: 0.7720
# Epoch: 022, Loss: 0.0187, Accuracy: 0.7930
# Epoch: 023, Loss: 0.0192, Accuracy: 0.7690
# Epoch: 024, Loss: 0.0151, Accuracy: 0.7890
# Epoch: 025, Loss: 0.0158, Accuracy: 0.7700
# Epoch: 026, Loss: 0.0123, Accuracy: 0.7830
Loss: 0.0000, Accuracy: 0.7490
# Epoch: 085, Loss: 0.0000, Accuracy: 0.7390
# Epoch: 086, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 087, Loss: 0.0000, Accuracy: 0.7400
# Epoch: 088, Loss: 0.0000, Accuracy: 0.7500
# Epoch: 089, Loss: 0.0000, Accuracy: 0.7410
# Epoch: 090, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 091, Loss: 0.0000, Accuracy: 0.7410
# Epoch: 092, Loss: 0.0000, Accuracy: 0.7540
# Epoch: 093, Loss: 0.0000, Accuracy: 0.7410
# Epoch: 094, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 095, Loss: 0.0000, Accuracy: 0.7420
# Epoch: 096, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 097, Loss: 0.0000, Accuracy: 0.7420
# Epoch: 098, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 099, Loss: 0.0000, Accuracy: 0.7440
# Epoch: 100, Loss: 0.0000, Accuracy: 0.7540
# Epoch: 101, Loss: 0.0000, Accuracy: 0.7450
# Epoch: 102, Loss: 0.0000, Accuracy: 0.7550
# Epoch: 103, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 104, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 105, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 106, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 107, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 108, Loss: 0.0000, Accuracy: 0.7540
# Epoch: 109, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 110, Loss: 0.0000, Accuracy: 0.7550
# Epoch: 111, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 112, Loss: 0.0000, Accuracy: 0.7540
# Epoch: 113, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 114, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 115, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 116, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 117, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 118, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 119, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 120, Loss: 0.0000, Accuracy: 0.7500
# Epoch: 121, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 122, Loss: 0.0000, Accuracy: 0.7500
# Epoch: 123, Loss: 0.0000, Accuracy: 0.7500
# Epoch: 124, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 125, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 126, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 127, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 128, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 129, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 130, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 131, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 132, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 133, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 134, Loss: 0.0000, Accuracy: 0.7500
# Epoch: 135, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 136, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 137, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 138, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 139, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 140, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 141, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 142, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 143, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 144, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 145, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 146, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 147, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 148, Loss: 0.0000, Accuracy: 0.7530
# Epoch: 149, Loss: 0.0000, Accuracy: 0.7520
# Epoch: 150, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 151, Loss: 0.0000, Accuracy: 0.7510
# Epoch: 152, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 153, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 154, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 155, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 156, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 157, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 158, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 159, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 160, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 161, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 162, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 163, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 164, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 165, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 166, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 167, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 168, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 169, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 170, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 171, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 172, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 173, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 174, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 175, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 176, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 177, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 178, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 179, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 180, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 181, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 182, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 183, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 184, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 185, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 186, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 187, Loss: 0.0000, Accuracy: 0.7460
# Epoch: 188, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 189, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 190, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 191, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 192, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 193, Loss: 0.0000, Accuracy: 0.7470
# Epoch: 194, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 195, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 196, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 197, Loss: 0.0000, Accuracy: 0.7480
# Epoch: 198, Loss: 0.0000, Accuracy: 0.7490
# Epoch: 199, Loss: 0.0000, Accuracy: 0.7490

# %%
torch.save(model.state_dict(), 'cora_gt.pt')

# %% [markdown]
# The following shows the 10 nodes with the highest degree.

# %%
# import networkx as nx
# from dgl import to_networkx
# import matplotlib.pyplot as plt

# G = to_networkx(g)
# pos = nx.spring_layout(G, seed=42)
# cent = nx.degree_centrality(G)
# node_size = list(map(lambda x: x * 500, cent.values()))
# cent_array = np.array(list(cent.values()))
# threshold = sorted(cent_array, reverse=True)[50]
# print("threshold", threshold)
# cent_bin = np.where(cent_array >= threshold, 1, 0.1)
# plt.figure(figsize=(12, 12))
# nodes = nx.draw_networkx_nodes(G, pos, node_size=node_size,
#                                cmap=plt.cm.plasma,
#                                node_color=cent_bin,
#                                nodelist=list(cent.keys()),
#                                alpha=cent_bin)
# edges = nx.draw_networkx_edges(G, pos, width=0.25, alpha=0.3)
# plt.show()

# %% [markdown]
# This shows me the node with the highest degree.

# %%
# threshold = sorted(cent_array, reverse=True)[0]
# print("threshold", threshold)
# cent_bin = np.where(cent_array >= threshold, 1, 0.1)
# plt.figure(figsize=(12, 12))
# nodes = nx.draw_networkx_nodes(G, pos, node_size=node_size,
#                                cmap=plt.cm.plasma,
#                                node_color=cent_bin,
#                                nodelist=list(cent.keys()),
#                                alpha=cent_bin)
# edges = nx.draw_networkx_edges(G, pos, width=0.25, alpha=0.3)
# plt.show()
