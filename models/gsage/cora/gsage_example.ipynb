# %%
# these warnings are fine. you can ignore them.
import random, math

import sys
sys.path.append('../../../')
from util import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Imports finished.")
# Out:
# Imports finished.

# %%
cora_dataset = Planetoid(root='/tmp/Cora', name='Cora')
data = cora_dataset[0]
data = data.to(device, 'x', 'edge_index')

model = get_model(data.num_node_features, 64, 7, 'cora', Models.GSAGE)

ground_truth = get_ground_truth(model, data, Models.GSAGE, testMask = False)
print(ground_truth)
# Out:
# 0.508
