# %%
# these warnings are fine. you can ignore them.
import random, math
from deeprobust.graph.data import Dataset as RDDataset

import sys
sys.path.append('../../../')
from util import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Imports finished.")
# Out:
# Imports finished.

# %%
data = RDDataset(root='/tmp/', name="cora")
adj, features, labels = data.adj, data.features, data.labels
idx_train, idx_val, idx_test = data.idx_train, data.idx_val, data.idx_test

idx = np.concatenate([idx_train, idx_val, idx_test], axis=0)
np.sort(idx)

in_feats = features.shape[1]
h_feats = 64
num_classes = labels.max() + 1

model = get_model('../../../', in_feats, h_feats, num_classes, 'cora', Models.GCNJACCARD)
# model.fit(features, data.adj, labels, idx_train, idx_val, threshold=0.01)
# model.eval()
# ground_truth = get_ground_truth(model, idx, testMask = False, isJaccard=True)
# print(ground_truth)
model.test(idx_test)
# Out:
# Loading cora dataset...
# Selecting 1 largest connected components
# Loading cora dataset...
# Selecting 1 largest connected components
# removed 548 edges in the original graph
# Test set results: loss= 0.5389 accuracy= 0.8395
# 0.8395372233400402
