# %%
import torch
import numpy as np
import torch.nn.functional as F
from deeprobust.graph.defense import GCNJaccard
from deeprobust.graph.utils import *
from deeprobust.graph.data import Dataset, PrePtbDataset
import argparse

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data = Dataset(root='/tmp/', name="cora")
adj, features, labels = data.adj, data.features, data.labels
idx_train, idx_val, idx_test = data.idx_train, data.idx_val, data.idx_test
# Out:
# Loading cora dataset...
# Selecting 1 largest connected components

# %%
in_feats = features.shape[1]
h_feats = 64
num_classes = labels.max() + 1

model = GCNJaccard(nfeat=in_feats, nclass=num_classes,
                nhid=h_feats, device=device)

model = model.to(device)

# %%
print('=== testing GCN-Jaccard on regular graph ===')
model.fit(features, data.adj, labels, idx_train, idx_val, threshold=0.01)
model.eval()
output = model.test(idx_test)
# Out:
# === testing GCN-Jaccard on regular graph ===
# removed 548 edges in the original graph
# === training gcn model ===
# Epoch 0, training loss: 2.0161447525024414
# Epoch 10, training loss: 0.28666943311691284
# Epoch 20, training loss: 0.0636061578989029
# Epoch 30, training loss: 0.03526848554611206
# Epoch 40, training loss: 0.017723971977829933
# Epoch 50, training loss: 0.021908434107899666
# Epoch 60, training loss: 0.024404773488640785
# Epoch 70, training loss: 0.02731539122760296
# Epoch 80, training loss: 0.023999737575650215
# Epoch 90, training loss: 0.022422024980187416
# Epoch 100, training loss: 0.020039832219481468
# Epoch 110, training loss: 0.018764128908514977
# Epoch 120, training loss: 0.019336925819516182
# Epoch 130, training loss: 0.02129187621176243
# Epoch 140, training loss: 0.016405005007982254
# Epoch 150, training loss: 0.01288101077079773
# Epoch 160, training loss: 0.017065953463315964
# Epoch 170, training loss: 0.014680197462439537
# Epoch 180, training loss: 0.01181630790233612
# Epoch 190, training loss: 0.017312517389655113
# === picking the best model according to the performance on validation ===
# Test set results: loss= 0.5457 accuracy= 0.8249
# output: 0.8249496981891349

# %%
torch.save(model, 'cora_gcn_jaccard.pt')
