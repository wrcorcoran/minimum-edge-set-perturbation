# %%
import torch
import numpy as np
import torch.nn.functional as F
from deeprobust.graph.defense import GCNJaccard
from deeprobust.graph.utils import *
from deeprobust.graph.data import Dataset, PrePtbDataset
import argparse

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data = Dataset(root='/tmp/', name="pubmed")
adj, features, labels = data.adj, data.features, data.labels
idx_train, idx_val, idx_test = data.idx_train, data.idx_val, data.idx_test
# Out:
# Loading pubmed dataset...

# %%
in_feats = features.shape[1]
h_feats = 64
num_classes = labels.max() + 1

model = GCNJaccard(nfeat=in_feats, nclass=num_classes,
                nhid=h_feats, device=device)

model = model.to(device)

# %%
print('=== testing GCN-Jaccard on regular graph ===')
model.fit(features, data.adj, labels, idx_train, idx_val, threshold=0.01)
model.eval()
output = model.test(idx_test)
# Out:
# === testing GCN-Jaccard on regular graph ===
# removed 39 edges in the original graph
# === training gcn model ===
# Epoch 0, training loss: 1.0690219402313232
# Epoch 10, training loss: 0.7309954762458801
# Epoch 20, training loss: 0.5075670480728149
# Epoch 30, training loss: 0.41828590631484985
# Epoch 40, training loss: 0.3740675747394562
# Epoch 50, training loss: 0.3504508137702942
# Epoch 60, training loss: 0.3323485851287842
# Epoch 70, training loss: 0.32343974709510803
# Epoch 80, training loss: 0.30293920636177063
# Epoch 90, training loss: 0.29881834983825684
# Epoch 100, training loss: 0.29194924235343933
# Epoch 110, training loss: 0.2801741659641266
# Epoch 120, training loss: 0.28006690740585327
# Epoch 130, training loss: 0.2722589373588562
# Epoch 140, training loss: 0.2722924053668976
# Epoch 150, training loss: 0.268434077501297
# Epoch 160, training loss: 0.26544657349586487
# Epoch 170, training loss: 0.2629537582397461
# Epoch 180, training loss: 0.2569916844367981
# Epoch 190, training loss: 0.2548903822898865
# === picking the best model according to the performance on validation ===
# Test set results: loss= 0.3695 accuracy= 0.8662

# %%
torch.save(model.state_dict(), 'pubmed_gcn_jaccard.pt')
