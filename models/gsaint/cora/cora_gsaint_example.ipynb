# %%
# these warnings are fine. you can ignore them.
import random, math

import sys
sys.path.append('../../../')
from util import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Imports finished.")
# Out:
# Imports finished.

# %%
dataset = Dataset(root='/tmp/Cora', name='Cora', device=device)
data, in_feats, h_feats, num_classes = dataset.get_data()

model = get_model(in_feats, h_feats, num_classes, 'cora', Models.GSAINT, dataset)

ground_truth = get_ground_truth(model, data, Models.GSAINT, testMask = False)
print(ground_truth)
# Out:
# 0.64
